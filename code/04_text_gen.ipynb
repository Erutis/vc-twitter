# %% [markdown]
# # GPT-2-Simple
#
# It is recommended to run this notebook in Google Colab.
#
# This is a shortened version of [this Colab notebook](https://colab.research.google.com/drive/1VLG8e7YSEwypxU-noRNhsv5dW4NfTGce).
# It takes an already fine-tuned model and generates text with it.
# The model is based on OpenAI's gpt-2 and is simplified. The original code by Max Woolf can be found [here](https://github.com/minimaxir/gpt-2-simple).

# %%
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files

# %% [markdown]
# # Load a trained model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, checkpoint_dir='/content/drive/MyDrive/checkpoint', run_name='run2')
# Out:
# Loading checkpoint /content/drive/MyDrive/checkpoint/run2/model-1000
# INFO:tensorflow:Restoring parameters from /content/drive/MyDrive/checkpoint/run2/model-1000

# %% [markdown]
# # Generate text from trained model

# %%
gpt2.generate(sess, checkpoint_dir='/content/drive/MyDrive/checkpoint',  run_name='run2', length=70)
# Out:
# the last great oligarchical regime collapse was in 1990? exuberantly so.
# the great majority of billionaires are white.
# classic elitist mirren-man bullshit.
# but if contemporary liberalism is the ideology of imperial academia, then what is the ideology of "progress" in particular?
# is the university the
